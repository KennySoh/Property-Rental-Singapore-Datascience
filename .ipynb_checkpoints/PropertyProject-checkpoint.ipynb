# %%
import pandas as pd
import math
import numpy as np
from sklearn import preprocessing, svm
from sklearn.linear_model import LinearRegression
from sklearn.model_selection import train_test_split
from datetime import datetime
from IPython.display import display, HTML
from matplotlib import colors
import matplotlib
import matplotlib.pyplot as plt
import seaborn as sns

"""
Rental Data Set from Nov-15 to Nov-18
eg. df_1_5 means district 1 to 5
"""
# Large Dataset
df_1_5=pd.read_csv('ura_1_5.csv',skiprows=1)
df_1_5=df_1_5[:-6] #Get rid of tail non-data description
# display(df_1_5.tail(2))

df_6_10=pd.read_csv('ura_6_10.csv',skiprows=1)
df_6_10=df_6_10[:-6] #Get rid of tail non-data description
# display(df_6_10.tail(2))

df_11_15=pd.read_csv('ura_11_15.csv',skiprows=1)
df_11_15=df_11_15[:-6] #Get rid of tail non-data description
# display(df_11_15.tail(2))

df_16_20=pd.read_csv('ura_16_20.csv',skiprows=1)
df_16_20=df_16_20[:-6] #Get rid of tail non-data description
# display(df_16_20.tail(2))

df_21_26=pd.read_csv('ura_21_26.csv',skiprows=1)
df_21_26=df_21_26[:-6] #Get rid of tail non-data description
# display(df_21_26.tail(2))

df_27_28=pd.read_csv('ura_27_28.csv',skiprows=1)
df_27_28=df_27_28[:-6] #Get rid of tail non-data description
# display(df_27_28.tail(2))

print("====================All URA Dataframe=======================")
df = pd.concat([df_1_5, df_6_10,df_11_15,df_16_20,df_21_26,df_27_28], ignore_index=True)
display(df.tail(2))

"""
Dictionary mapping property-> Lat, Long 
eg. df_dict['lat']['JI XIANG COURT'] -> 1.264218
"""
df_dict=pd.read_csv('property_project.csv')
df_dict=df_dict[['address','lat','long']]
df_dict=df_dict.set_index('address').to_dict()



dates_dict={
    "Jan": 1,
    "Feb": 2,
    "Mar": 3,
    "Apr": 4,
    "May": 5,
    "Jun":6,
    "Jul":7,
    "Aug":8,
    "Sep":9,
    "Oct":10,
    "Nov":11,
    "Dec":12    
}

# Preprocessing

# Some Data preprocessing for uniformity
def g(x):
    if(x=='ANGULLIA PARK RESIDENCES @ ORCHARD'):
        return 'ANGULLIA PARK RESIDENCES@ORCHARD'
    return x
df['Building/Project Name'] = df['Building/Project Name'].apply(g)

# -Converting Floor Area(1400 to 1500 -> 1450)
def f(x):
    try:
        return sum([int(item) for item in str(x).split(' to ')])/2
    except:
        return 0
df['Floor Area (sq ft)'] = df['Floor Area (sq ft)'].apply(f)

# -Monthly rental/ sqft> Monthly rental Psf
df['Monthly Rent/ psf']=df['Monthly Gross Rent($)']/df['Floor Area (sq ft)']

# -Building/Project Name , District -> lat, long
df['lat']=df['Building/Project Name'].apply(lambda x:df_dict['lat'][x])
df['long']=df['Building/Project Name'].apply(lambda x:df_dict['long'][x])

# -Lease Commencement Date(string)-> date(int)
def g(x):
    m,y=x.split('-')
    return pd.Timestamp(int(y),dates_dict[m],1).toordinal()
df['Lease Commencement Date']=df['Lease Commencement Date'].apply(g).astype(float)

# Removing data with missing no of bedroom
df['No. of Bedroom(for Non-Landed Only)']=df['No. of Bedroom(for Non-Landed Only)'].replace('na*',np.NaN)
df=df.dropna()

# Removing data with Floor Area<50
df = df.drop(df[df["Floor Area (sq ft)"]<50].index)

# Rename for coloumns names 
df.rename(columns={'No. of Bedroom(for Non-Landed Only)':'no_bedroom'}, inplace=True)# Rename Bed Room
df=df.rename(index=str, columns={"Building/Project Name":"project","Street Name":"street_name","Type":"type","Monthly Gross Rent($)": "monthly_gross_rent", "Monthly Rent/ psf": "monthly_rent_psf","Postal District":"district_f","lat": "lat","long": "long","no_bedroom": "no_bedroom","Floor Area (sq ft)": "floor_area","Lease Commencement Date": "date" })

df['no_bedroom']=df['no_bedroom'].astype(float)
df['floor_area']=df['floor_area'].astype(float)

print("====================Old Preprocessed Dataframe (name: df ->liyang has some dependencies #bedroom counts)=======================")
df=df.drop(['S/N','type'], axis=1)
display(df.head(3))

print("====================Preprocessed Dataframe (name: df_prep)=======================")
# # consolidaiton of Data
df_prep=df.drop(['project','street_name','date'], axis=1)
display(df_prep.tail(3))
# Out:
# ====================All URA Dataframe=======================
#          S/N Building/Project Name    Street Name  Postal District  \
# 223714  4680        H2O RESIDENCES  FERNVALE LINK             28.0
# 223715  4681        H2O RESIDENCES  FERNVALE LINK             28.0
#
#                          Type No. of Bedroom(for Non-Landed Only)  \
# 223714  Non-landed Properties                                   3
# 223715  Non-landed Properties                                   3
#
#         Monthly Gross Rent($) Floor Area (sq ft) Lease Commencement Date
# 223714                 2700.0       1100 to 1200                Nov-2015
# 223715                 2500.0       1100 to 1200                Nov-2015
# ====================Old Preprocessed Dataframe (name: df ->liyang has some dependencies #bedroom counts)=======================
#                 project        street_name  district_f  no_bedroom  \
# 1   HIGHLINE RESIDENCES      KIM TIAN ROAD         3.0         3.0
# ...

# %%
plt.figure(figsize=(15,10))
vmin = np.min(df.monthly_rent_psf)
vmax = np.max(df.monthly_rent_psf)
norm = colors.LogNorm(vmin*2,vmax/3)
plt.scatter(df.long,df.lat, marker='*',c=df.monthly_rent_psf,norm=norm,cmap='jet') 
plt.xlabel('Longitude')
plt.ylabel('Latituede')
plt.title('House Price by Geography')
clb = plt.colorbar() 
clb.ax.set_title('monthly_rent_psf')
# Out:
# Text(0.5,1,'monthly_rent_psf')

# %%
from IPython.display import HTML, display
import tabulate

# Count of project being rented,
# Count of Bed Room

# Dataframe by Bedroom Sizes

bedroom_1=df[(df.no_bedroom>0.9)&(df.no_bedroom <1.1)]
bedroom_2=df[(df.no_bedroom>1.9)&(df.no_bedroom <2.1)]
bedroom_3=df[(df.no_bedroom>2.9)&(df.no_bedroom <3.1)]
bedroom_4=df[(df.no_bedroom>3.9)&(df.no_bedroom <4.1)]
bedroom_5=df[(df.no_bedroom>4.9)&(df.no_bedroom <5.1)]
bedroom_6=df[(df.no_bedroom>5.9)&(df.no_bedroom <6.1)]
bedroom_8=df[(df.no_bedroom>7.9)&(df.no_bedroom <8.1)]

bedroom_1_c=bedroom_1.count()
bedroom_2_c=bedroom_2.count()
bedroom_3_c=bedroom_3.count()
bedroom_4_c=bedroom_4.count()
bedroom_5_c=bedroom_5.count()
bedroom_6_c=bedroom_6.count()
bedroom_8_c=bedroom_8.count()

# print("1_Bdrm: ",bedroom_1_c['no_bedroom'],"\n2_Bdrm: ", bedroom_2_c['no_bedroom'],"\n3_Bdrm: ",bedroom_3_c['no_bedroom'],"\n4_Bdrm: ",bedroom_4_c['no_bedroom'],"\n5_Bdrm: ",bedroom_5_c['no_bedroom'],"\n6_Bdrm: ",bedroom_6_c['no_bedroom'],"\n8_Bdrm: ",bedroom_8_c['no_bedroom'])
# display(bedroom_1.head(1))
table=[["1_Bdrm: ",bedroom_1_c['no_bedroom']],
       ["2_Bdrm: ", bedroom_2_c['no_bedroom']],
       ["3_Bdrm: ",bedroom_3_c['no_bedroom']],
       ["4_Bdrm: ",bedroom_4_c['no_bedroom']],
       ["5_Bdrm: ",bedroom_5_c['no_bedroom']],
       ["6_Bdrm: ",bedroom_6_c['no_bedroom']],
       ["\n8_Bdrm: ",bedroom_8_c['no_bedroom']]]
display(HTML(tabulate.tabulate(table, tablefmt='html')))


df_o=bedroom_1
# 1 Bedroom seperated into district
bedroom_1_1=df_o[(df_o.district_f>0.9)&(df_o.district_f <1.1)]
bedroom_1_2=df_o[(df_o.district_f>1.9)&(df_o.district_f <2.1)]
bedroom_1_3=df_o[(df_o.district_f>2.9)&(df_o.district_f <3.1)]
bedroom_1_4=df_o[(df_o.district_f>3.9)&(df_o.district_f <4.1)]
bedroom_1_5=df_o[(df_o.district_f>4.9)&(df_o.district_f <5.1)]
bedroom_1_6=df_o[(df_o.district_f>5.9)&(df_o.district_f <6.1)]
bedroom_1_7=df_o[(df_o.district_f>6.9)&(df_o.district_f <7.1)]
bedroom_1_8=df_o[(df_o.district_f>7.9)&(df_o.district_f <8.1)]
bedroom_1_9=df_o[(df_o.district_f>8.9)&(df_o.district_f <9.1)]
bedroom_1_10=df_o[(df_o.district_f>9.9)&(df_o.district_f <10.1)]
bedroom_1_11=df_o[(df_o.district_f>10.9)&(df_o.district_f <11.1)]
bedroom_1_12=df_o[(df_o.district_f>11.9)&(df_o.district_f <12.1)]
bedroom_1_13=df_o[(df_o.district_f>12.9)&(df_o.district_f <13.1)]
bedroom_1_14=df_o[(df_o.district_f>13.9)&(df_o.district_f <14.1)]
bedroom_1_15=df_o[(df_o.district_f>14.9)&(df_o.district_f <15.1)]
bedroom_1_16=df_o[(df_o.district_f>15.9)&(df_o.district_f <16.1)]
bedroom_1_17=df_o[(df_o.district_f>16.9)&(df_o.district_f <17.1)]
bedroom_1_18=df_o[(df_o.district_f>17.9)&(df_o.district_f <18.1)]
bedroom_1_19=df_o[(df_o.district_f>18.9)&(df_o.district_f <19.1)]
bedroom_1_20=df_o[(df_o.district_f>19.9)&(df_o.district_f <20.1)]
bedroom_1_21=df_o[(df_o.district_f>20.9)&(df_o.district_f <21.1)]
bedroom_1_22=df_o[(df_o.district_f>21.9)&(df_o.district_f <22.1)]
bedroom_1_23=df_o[(df_o.district_f>22.9)&(df_o.district_f <23.1)]
bedroom_1_24=0 #No Non-Private Properties in district 24
bedroom_1_25=df_o[(df_o.district_f>24.9)&(df_o.district_f <25.1)]
bedroom_1_26=df_o[(df_o.district_f>25.9)&(df_o.district_f <26.1)]
bedroom_1_27=df_o[(df_o.district_f>26.9)&(df_o.district_f <27.1)]
bedroom_1_28=df_o[(df_o.district_f>27.9)&(df_o.district_f <28.1)]

bedroom_1_1_c=bedroom_1_1.count()



df_o=bedroom_2
# 2 Bedroom seperated into district
bedroom_2_1=df_o[(df_o.district_f>0.9)&(df_o.district_f <1.1)]
bedroom_2_2=df_o[(df_o.district_f>1.9)&(df_o.district_f <2.1)]
bedroom_2_3=df_o[(df_o.district_f>2.9)&(df_o.district_f <3.1)]
bedroom_2_4=df_o[(df_o.district_f>3.9)&(df_o.district_f <4.1)]
bedroom_2_5=df_o[(df_o.district_f>4.9)&(df_o.district_f <5.1)]
bedroom_2_6=df_o[(df_o.district_f>5.9)&(df_o.district_f <6.1)]
bedroom_2_7=df_o[(df_o.district_f>6.9)&(df_o.district_f <7.1)]
bedroom_2_8=df_o[(df_o.district_f>7.9)&(df_o.district_f <8.1)]
bedroom_2_9=df_o[(df_o.district_f>8.9)&(df_o.district_f <9.1)]
bedroom_2_10=df_o[(df_o.district_f>9.9)&(df_o.district_f <10.1)]
bedroom_2_11=df_o[(df_o.district_f>10.9)&(df_o.district_f <11.1)]
bedroom_2_12=df_o[(df_o.district_f>11.9)&(df_o.district_f <12.1)]
bedroom_2_13=df_o[(df_o.district_f>12.9)&(df_o.district_f <13.1)]
bedroom_2_14=df_o[(df_o.district_f>13.9)&(df_o.district_f <14.1)]
bedroom_2_15=df_o[(df_o.district_f>14.9)&(df_o.district_f <15.1)]
bedroom_2_16=df_o[(df_o.district_f>15.9)&(df_o.district_f <16.1)]
bedroom_2_17=df_o[(df_o.district_f>16.9)&(df_o.district_f <17.1)]
bedroom_2_18=df_o[(df_o.district_f>17.9)&(df_o.district_f <18.1)]
bedroom_2_19=df_o[(df_o.district_f>18.9)&(df_o.district_f <19.1)]
bedroom_2_20=df_o[(df_o.district_f>19.9)&(df_o.district_f <20.1)]
bedroom_2_21=df_o[(df_o.district_f>20.9)&(df_o.district_f <21.1)]
bedroom_2_22=df_o[(df_o.district_f>21.9)&(df_o.district_f <22.1)]
bedroom_2_23=df_o[(df_o.district_f>22.9)&(df_o.district_f <23.1)]
bedroom_2_24=0 #No Non-Private Properties in district 24
bedroom_2_25=df_o[(df_o.district_f>24.9)&(df_o.district_f <25.1)]
bedroom_2_26=df_o[(df_o.district_f>25.9)&(df_o.district_f <26.1)]
bedroom_2_27=df_o[(df_o.district_f>26.9)&(df_o.district_f <27.1)]
bedroom_2_28=df_o[(df_o.district_f>27.9)&(df_o.district_f <28.1)]

df_o=bedroom_3
# 3 Bedroom seperated into district
bedroom_3_1=df_o[(df_o.district_f>0.9)&(df_o.district_f <1.1)]
bedroom_3_2=df_o[(df_o.district_f>1.9)&(df_o.district_f <2.1)]
bedroom_3_3=df_o[(df_o.district_f>2.9)&(df_o.district_f <3.1)]
bedroom_3_4=df_o[(df_o.district_f>3.9)&(df_o.district_f <4.1)]
bedroom_3_5=df_o[(df_o.district_f>4.9)&(df_o.district_f <5.1)]
bedroom_3_6=df_o[(df_o.district_f>5.9)&(df_o.district_f <6.1)]
bedroom_3_7=df_o[(df_o.district_f>6.9)&(df_o.district_f <7.1)]
bedroom_3_8=df_o[(df_o.district_f>7.9)&(df_o.district_f <8.1)]
bedroom_3_9=df_o[(df_o.district_f>8.9)&(df_o.district_f <9.1)]
bedroom_3_10=df_o[(df_o.district_f>9.9)&(df_o.district_f <10.1)]
bedroom_3_11=df_o[(df_o.district_f>10.9)&(df_o.district_f <11.1)]
bedroom_3_12=df_o[(df_o.district_f>11.9)&(df_o.district_f <12.1)]
bedroom_3_13=df_o[(df_o.district_f>12.9)&(df_o.district_f <13.1)]
bedroom_3_14=df_o[(df_o.district_f>13.9)&(df_o.district_f <14.1)]
bedroom_3_15=df_o[(df_o.district_f>14.9)&(df_o.district_f <15.1)]
bedroom_3_16=df_o[(df_o.district_f>15.9)&(df_o.district_f <16.1)]
bedroom_3_17=df_o[(df_o.district_f>16.9)&(df_o.district_f <17.1)]
bedroom_3_18=df_o[(df_o.district_f>17.9)&(df_o.district_f <18.1)]
bedroom_3_19=df_o[(df_o.district_f>18.9)&(df_o.district_f <19.1)]
bedroom_3_20=df_o[(df_o.district_f>19.9)&(df_o.district_f <20.1)]
bedroom_3_21=df_o[(df_o.district_f>20.9)&(df_o.district_f <21.1)]
bedroom_3_22=df_o[(df_o.district_f>21.9)&(df_o.district_f <22.1)]
bedroom_3_23=df_o[(df_o.district_f>22.9)&(df_o.district_f <23.1)]
bedroom_3_24=0 #No Non-Private Properties in district 24
bedroom_3_25=df_o[(df_o.district_f>24.9)&(df_o.district_f <25.1)]
bedroom_3_26=df_o[(df_o.district_f>25.9)&(df_o.district_f <26.1)]
bedroom_3_27=df_o[(df_o.district_f>26.9)&(df_o.district_f <27.1)]
bedroom_3_28=df_o[(df_o.district_f>27.9)&(df_o.district_f <28.1)]

df_o=bedroom_4
# 4 Bedroom seperated into district
bedroom_4_1=df_o[(df_o.district_f>0.9)&(df_o.district_f <1.1)]
bedroom_4_2=df_o[(df_o.district_f>1.9)&(df_o.district_f <2.1)]
bedroom_4_3=df_o[(df_o.district_f>2.9)&(df_o.district_f <3.1)]
bedroom_4_4=df_o[(df_o.district_f>3.9)&(df_o.district_f <4.1)]
bedroom_4_5=df_o[(df_o.district_f>4.9)&(df_o.district_f <5.1)]
bedroom_4_6=df_o[(df_o.district_f>5.9)&(df_o.district_f <6.1)]
bedroom_4_7=df_o[(df_o.district_f>6.9)&(df_o.district_f <7.1)]
bedroom_4_8=df_o[(df_o.district_f>7.9)&(df_o.district_f <8.1)]
bedroom_4_9=df_o[(df_o.district_f>8.9)&(df_o.district_f <9.1)]
bedroom_4_10=df_o[(df_o.district_f>9.9)&(df_o.district_f <10.1)]
bedroom_4_11=df_o[(df_o.district_f>10.9)&(df_o.district_f <11.1)]
bedroom_4_12=df_o[(df_o.district_f>11.9)&(df_o.district_f <12.1)]
bedroom_4_13=df_o[(df_o.district_f>12.9)&(df_o.district_f <13.1)]
bedroom_4_14=df_o[(df_o.district_f>13.9)&(df_o.district_f <14.1)]
bedroom_4_15=df_o[(df_o.district_f>14.9)&(df_o.district_f <15.1)]
bedroom_4_16=df_o[(df_o.district_f>15.9)&(df_o.district_f <16.1)]
bedroom_4_17=df_o[(df_o.district_f>16.9)&(df_o.district_f <17.1)]
bedroom_4_18=df_o[(df_o.district_f>17.9)&(df_o.district_f <18.1)]
bedroom_4_19=df_o[(df_o.district_f>18.9)&(df_o.district_f <19.1)]
bedroom_4_20=df_o[(df_o.district_f>19.9)&(df_o.district_f <20.1)]
bedroom_4_21=df_o[(df_o.district_f>20.9)&(df_o.district_f <21.1)]
bedroom_4_22=df_o[(df_o.district_f>21.9)&(df_o.district_f <22.1)]
bedroom_4_23=df_o[(df_o.district_f>22.9)&(df_o.district_f <23.1)]
bedroom_4_24=0 #No Non-Private Properties in district 24
bedroom_4_25=df_o[(df_o.district_f>24.9)&(df_o.district_f <25.1)]
bedroom_4_26=df_o[(df_o.district_f>25.9)&(df_o.district_f <26.1)]
bedroom_4_27=df_o[(df_o.district_f>26.9)&(df_o.district_f <27.1)]
bedroom_4_28=df_o[(df_o.district_f>27.9)&(df_o.district_f <28.1)]

df_o=bedroom_5
# 5 Bedroom seperated into district
bedroom_5_1=df_o[(df_o.district_f>0.9)&(df_o.district_f <1.1)]
bedroom_5_2=df_o[(df_o.district_f>1.9)&(df_o.district_f <2.1)]
bedroom_5_3=df_o[(df_o.district_f>2.9)&(df_o.district_f <3.1)]
bedroom_5_4=df_o[(df_o.district_f>3.9)&(df_o.district_f <4.1)]
bedroom_5_5=df_o[(df_o.district_f>4.9)&(df_o.district_f <5.1)]
bedroom_5_6=df_o[(df_o.district_f>5.9)&(df_o.district_f <6.1)]
bedroom_5_7=df_o[(df_o.district_f>6.9)&(df_o.district_f <7.1)]
bedroom_5_8=df_o[(df_o.district_f>7.9)&(df_o.district_f <8.1)]
bedroom_5_9=df_o[(df_o.district_f>8.9)&(df_o.district_f <9.1)]
bedroom_5_10=df_o[(df_o.district_f>9.9)&(df_o.district_f <10.1)]
bedroom_5_11=df_o[(df_o.district_f>10.9)&(df_o.district_f <11.1)]
bedroom_5_12=df_o[(df_o.district_f>11.9)&(df_o.district_f <12.1)]
bedroom_5_13=df_o[(df_o.district_f>12.9)&(df_o.district_f <13.1)]
bedroom_5_14=df_o[(df_o.district_f>13.9)&(df_o.district_f <14.1)]
bedroom_5_15=df_o[(df_o.district_f>14.9)&(df_o.district_f <15.1)]
bedroom_5_16=df_o[(df_o.district_f>15.9)&(df_o.district_f <16.1)]
bedroom_5_17=df_o[(df_o.district_f>16.9)&(df_o.district_f <17.1)]
bedroom_5_18=df_o[(df_o.district_f>17.9)&(df_o.district_f <18.1)]
bedroom_5_19=df_o[(df_o.district_f>18.9)&(df_o.district_f <19.1)]
bedroom_5_20=df_o[(df_o.district_f>19.9)&(df_o.district_f <20.1)]
bedroom_5_21=df_o[(df_o.district_f>20.9)&(df_o.district_f <21.1)]
bedroom_5_22=df_o[(df_o.district_f>21.9)&(df_o.district_f <22.1)]
bedroom_5_23=df_o[(df_o.district_f>22.9)&(df_o.district_f <23.1)]
bedroom_5_24=0#No Non-Private Properties in district 24
bedroom_5_25=df_o[(df_o.district_f>24.9)&(df_o.district_f <25.1)]
bedroom_5_26=df_o[(df_o.district_f>25.9)&(df_o.district_f <26.1)]
bedroom_5_27=df_o[(df_o.district_f>26.9)&(df_o.district_f <27.1)]
bedroom_5_28=df_o[(df_o.district_f>27.9)&(df_o.district_f <28.1)]


table=[["","1_Bdrm: ","2_Bdrm: ","3_Bdrm: ","4_Bdrm: ","5_Bdrm: "],
       ["D1",bedroom_1_1.count()['no_bedroom'],bedroom_2_1.count()['no_bedroom'],bedroom_3_1.count()['no_bedroom'],bedroom_4_1.count()['no_bedroom'],bedroom_5_1.count()['no_bedroom']],
       ["D2",bedroom_1_2.count()['no_bedroom'],bedroom_2_2.count()['no_bedroom'],bedroom_3_2.count()['no_bedroom'],bedroom_4_2.count()['no_bedroom'],bedroom_5_2.count()['no_bedroom']],
       ["D3",bedroom_1_3.count()['no_bedroom'],bedroom_2_3.count()['no_bedroom'],bedroom_3_3.count()['no_bedroom'],bedroom_4_3.count()['no_bedroom'],bedroom_5_3.count()['no_bedroom']],
       ["D4",bedroom_1_4.count()['no_bedroom'],bedroom_2_4.count()['no_bedroom'],bedroom_3_4.count()['no_bedroom'],bedroom_4_4.count()['no_bedroom'],bedroom_5_4.count()['no_bedroom']],
       ["D5",bedroom_1_5.count()['no_bedroom'],bedroom_2_5.count()['no_bedroom'],bedroom_3_5.count()['no_bedroom'],bedroom_4_5.count()['no_bedroom'],bedroom_5_5.count()['no_bedroom']],
       ["D6",bedroom_1_6.count()['no_bedroom'],bedroom_2_6.count()['no_bedroom'],bedroom_3_6.count()['no_bedroom'],bedroom_4_6.count()['no_bedroom'],bedroom_5_6.count()['no_bedroom']],
       ["D7",bedroom_1_7.count()['no_bedroom'],bedroom_2_7.count()['no_bedroom'],bedroom_3_7.count()['no_bedroom'],bedroom_4_7.count()['no_bedroom'],bedroom_5_7.count()['no_bedroom']],
       ["D8",bedroom_1_8.count()['no_bedroom'],bedroom_2_8.count()['no_bedroom'],bedroom_3_8.count()['no_bedroom'],bedroom_4_8.count()['no_bedroom'],bedroom_5_8.count()['no_bedroom']],
       ["D9",bedroom_1_9.count()['no_bedroom'],bedroom_2_9.count()['no_bedroom'],bedroom_3_9.count()['no_bedroom'],bedroom_4_9.count()['no_bedroom'],bedroom_5_9.count()['no_bedroom']],
       ["D10",bedroom_1_10.count()['no_bedroom'],bedroom_2_10.count()['no_bedroom'],bedroom_3_10.count()['no_bedroom'],bedroom_4_10.count()['no_bedroom'],bedroom_5_10.count()['no_bedroom']],
       ["D11",bedroom_1_11.count()['no_bedroom'],bedroom_2_11.count()['no_bedroom'],bedroom_3_11.count()['no_bedroom'],bedroom_4_11.count()['no_bedroom'],bedroom_5_11.count()['no_bedroom']],
       ["D12",bedroom_1_12.count()['no_bedroom'],bedroom_2_12.count()['no_bedroom'],bedroom_3_12.count()['no_bedroom'],bedroom_4_12.count()['no_bedroom'],bedroom_5_12.count()['no_bedroom']],
       ["D13",bedroom_1_13.count()['no_bedroom'],bedroom_2_13.count()['no_bedroom'],bedroom_3_13.count()['no_bedroom'],bedroom_4_13.count()['no_bedroom'],bedroom_5_13.count()['no_bedroom']],
       ["D14",bedroom_1_14.count()['no_bedroom'],bedroom_2_14.count()['no_bedroom'],bedroom_3_14.count()['no_bedroom'],bedroom_4_14.count()['no_bedroom'],bedroom_5_14.count()['no_bedroom']],
       ["D15",bedroom_1_15.count()['no_bedroom'],bedroom_2_15.count()['no_bedroom'],bedroom_3_15.count()['no_bedroom'],bedroom_4_15.count()['no_bedroom'],bedroom_5_15.count()['no_bedroom']],
       ["D16",bedroom_1_16.count()['no_bedroom'],bedroom_2_16.count()['no_bedroom'],bedroom_3_16.count()['no_bedroom'],bedroom_4_16.count()['no_bedroom'],bedroom_5_16.count()['no_bedroom']],
       ["D17",bedroom_1_17.count()['no_bedroom'],bedroom_2_17.count()['no_bedroom'],bedroom_3_17.count()['no_bedroom'],bedroom_4_17.count()['no_bedroom'],bedroom_5_17.count()['no_bedroom']],
       ["D18",bedroom_1_18.count()['no_bedroom'],bedroom_2_18.count()['no_bedroom'],bedroom_3_18.count()['no_bedroom'],bedroom_4_18.count()['no_bedroom'],bedroom_5_18.count()['no_bedroom']],
       ["D19",bedroom_1_19.count()['no_bedroom'],bedroom_2_19.count()['no_bedroom'],bedroom_3_19.count()['no_bedroom'],bedroom_4_19.count()['no_bedroom'],bedroom_5_19.count()['no_bedroom']],
       ["D20",bedroom_1_20.count()['no_bedroom'],bedroom_2_20.count()['no_bedroom'],bedroom_3_20.count()['no_bedroom'],bedroom_4_20.count()['no_bedroom'],bedroom_5_20.count()['no_bedroom']],
       ["D21",bedroom_1_21.count()['no_bedroom'],bedroom_2_21.count()['no_bedroom'],bedroom_3_21.count()['no_bedroom'],bedroom_4_21.count()['no_bedroom'],bedroom_5_21.count()['no_bedroom']],
       ["D22",bedroom_1_22.count()['no_bedroom'],bedroom_2_22.count()['no_bedroom'],bedroom_3_22.count()['no_bedroom'],bedroom_4_22.count()['no_bedroom'],bedroom_5_22.count()['no_bedroom']],
       ["D23",bedroom_1_23.count()['no_bedroom'],bedroom_2_23.count()['no_bedroom'],bedroom_3_23.count()['no_bedroom'],bedroom_4_23.count()['no_bedroom'],bedroom_5_23.count()['no_bedroom']],
       ["D24",bedroom_1_24,bedroom_2_24,bedroom_3_24,bedroom_4_24,bedroom_5_24],
       ["D25",bedroom_1_25.count()['no_bedroom'],bedroom_2_25.count()['no_bedroom'],bedroom_3_25.count()['no_bedroom'],bedroom_4_25.count()['no_bedroom'],bedroom_5_25.count()['no_bedroom']],
       ["D26",bedroom_1_26.count()['no_bedroom'],bedroom_2_26.count()['no_bedroom'],bedroom_3_26.count()['no_bedroom'],bedroom_4_26.count()['no_bedroom'],bedroom_5_26.count()['no_bedroom']],
       ["D27",bedroom_1_27.count()['no_bedroom'],bedroom_2_27.count()['no_bedroom'],bedroom_3_27.count()['no_bedroom'],bedroom_4_27.count()['no_bedroom'],bedroom_5_27.count()['no_bedroom']],
       ["D28",bedroom_1_28.count()['no_bedroom'],bedroom_2_28.count()['no_bedroom'],bedroom_3_28.count()['no_bedroom'],bedroom_4_28.count()['no_bedroom'],bedroom_5_28.count()['no_bedroom']]
      ]
display(HTML(tabulate.tabulate(table, tablefmt='html')))
# Out:
# <table>
# <tbody>
# <tr><td>1_Bdrm:</td><td style="text-align: right;">41507</td></tr>
# <tr><td>2_Bdrm:</td><td style="text-align: right;">68563</td></tr>
# <tr><td>3_Bdrm:</td><td style="text-align: right;">72493</td></tr>
# <tr><td>4_Bdrm:</td><td style="text-align: right;">15266</td></tr>
# <tr><td>5_Bdrm:</td><td style="text-align: right;">  280</td></tr>
# <tr><td>6_Bdrm:</td><td style="text-align: right;">    9</td></tr>
# <tr><td>8_Bdrm:</td><td style="text-align: right;">    7</td></tr>
# </tbody>
# </table>
# <table>
# <tbody>
# <tr><td>   </td><td>1_Bdrm:</td><td>2_Bdrm:</td><td>3_Bdrm:</td><td>4_Bdrm:</td><td>5_Bdrm:</td></tr>
# <tr><td>D1 </td><td>2323   </td><td>1820   </td><td>898    </td><td>319    </td><td>0      </td></tr>
# <tr><td>D2 </td><td>2531   </td><td>1652   </td><td>224    </td><td>0      </td><td>0      </td></tr>
# <tr><td>D3 </td><td>1192   </td><td>2094   </td><td>2825   </td><td>381    </td><td>2      </td></tr>
# ...
